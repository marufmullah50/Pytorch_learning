# %% [markdown]
# # Auto grad

# %%
import math
import torch

# %%
# Diff of x^2
def dy_dx(x):
    return 2 * x

dy_dx(2)
# Out:
# 4

# %%
x = torch.tensor(3.0, requires_grad =True)  

#torch.tensor(3.0)

#This creates a PyTorch tensor with value: 3.0
#“Track all operations on x so I can compute gradients later.”

# %%
print(x)
# Out:
# tensor(3., requires_grad=True)

# %%
y = x**2

# %%
print(y)
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
#Differentiating y with respect to x dy/dx
#y.backward()

# %%
#x.grad 
# dy/dx = 2x -> at x=3.0
# No need the previous function now def

# %%
z = torch.sin(y)

# %%
#Compute the derivative dz/dx
z.backward()

# %%
x.grad # dz/dx  at x=3.0
# Out:
# tensor(-5.4668)

# %%
#Mid point can't  be counted as they are called intermediate points
y.grad
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_22232\3511053068.py:2: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\build\aten\src\ATen/core/TensorBody.h:494.)
#   y.grad

# %%
import torch

# Inputs
x = torch.tensor(6.7)  # Input feature
y = torch.tensor(0.0)  # True label (binary)

w = torch.tensor(1.0)  # Weight
b = torch.tensor(0.0)  # Bias

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8  # To prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# Forward pass
z = w * x + b  # Weighted sum (linear part)
y_pred = torch.sigmoid(z)  # Predicted probability

# Compute binary cross-entropy loss
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# Derivatives:
# 1. dL/d(y_pred): Loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred - y)/(y_pred*(1-y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw = x  # dz/dw = x
dz_db = 1  # dz/db = 1 (bias contributes directly to z)

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual Gradient of loss w.r.t weight (dw): 6.691762447357178
# Manual Gradient of loss w.r.t bias (db): 0.998770534992218

# %% [markdown]
# # Same with Auto grad

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0 , requires_grad = True)
b= torch.tensor(0.0 , requires_grad = True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z = w*x + b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy_loss(y_pred, y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
#Back propagation
loss.backward()

# %%
#Graduents
print(f"Auto Gradient of loss w.r.t weight (dw): {w.grad}")
print("\n")
print(f"Auto Gradient of loss w.r.t bias (db):{b.grad}")
# Out:
# Auto Gradient of loss w.r.t weight (dw): 6.6917619705200195
#
#
# Auto Gradient of loss w.r.t bias (db):0.9987704753875732

# %% [markdown]
# # Vector diff

# %%
x = torch.tensor([1.0, 2.0, 3.0] , requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
# x had 3 values, so its gradient will also have 3 values
# Partial differentiation
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %% [markdown]
# #Clearing Gradients

# %%
# If run a second time, the gradients will be accumulated
a = torch.tensor(2.0 , requires_grad=True)
a
# Out:
# tensor(2., requires_grad=True)

# %%
c = a**2
c
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
c.backward()

# %% [markdown]
# #Even Though x = 2 and result supposed to be 4
#  just because we run from c=a**2 ; 3times the result is 12
#  so we need
#  a.grad.zero_()

# %%
a.grad
# Out:
# tensor(12.)

# %% [markdown]
# #Corrected
# and thats why after each epoch grad cleared

# %%
m = torch.tensor(3.0 , requires_grad=True)
m
# Out:
# tensor(3., requires_grad=True)

# %%
n = m**3
n.backward()
m.grad
# Out:
# tensor(27.)

# %%
m.grad.zero_()
# Out:
# tensor(0.)

# %% [markdown]
# #Disable Gradient Tracking

# %%
# disable gradient tracking
o =  torch.tensor(4.0 , requires_grad=True)
o
# Out:
# tensor(4., requires_grad=True)

# %% [markdown]
# #After training , We don't need  grad tracking just forward pass

# %%
#Option 1 - requires_grad=(False)
#Option 2 - detach()
#Option 3 - torch.no_grad()

# %%
#Option 1 - requires_grad=(False)
o.requires_grad_(False)
# Out:
# tensor(4.)

# %%
o
# Out:
# tensor(4.)

# %%
p = o**4
p
# Out:
# tensor(256.)

# %%
p.backward()  # This will raise an error since o does not require gradients
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 p.backward()
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
# ...

# %%
# Detach method
q = torch.tensor(5.0 , requires_grad=True)
q
# Out:
# tensor(5., requires_grad=True)

# %%
n = q.detach()
n
# q is gradient tracking enabled but n is not
# Out:
# tensor(5.)

# %%
r = q**4
r
# Out:
# tensor(625., grad_fn=<PowBackward0>)

# %%
r1 = n**4
r1
# Out:
# tensor(625.)

# %%
 r.backward()

# %%
r1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 r1.backward()
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
# ...

# %%
# torch.no_grad() method
s = torch.tensor(6.0 , requires_grad=True)
s
# Out:
# tensor(6., requires_grad=True)

# %%
with torch.no_grad():
    t = s**4
    t.backward()  # This will raise an error since t does not require gradients
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[121], line 3
#       1 with torch.no_grad():
#       2     t = s**4
# ----> 3     t.backward()
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
# ...

# %%
t
# Out:
# tensor(1296.)
